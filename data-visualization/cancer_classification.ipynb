# %%
# import dependencies

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print("setup complete")
# Out:
# setup complete

# %%
df = pd.read_csv('./cancer.csv', index_col='Id')
df.head()
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# 8510653         520.0            0.10750             0.12700
# 8510824         273.9            0.10240             0.06492
# 854941          523.8            0.08983             0.03766
# 85713702        201.9            0.08600             0.05943
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %%
# Histograms for benign and maligant tumors

plt.title('Counts to compare between benign(B) and malignant(M) by area')
sns.histplot(data=df, x='Area (mean)', hue='Diagnosis')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: title={'center': 'Counts to compare between benign(B) and malignant(M) by area'}, xlabel='Area (mean)', ylabel='Count'>

# %%
# KDE plots for benign and malignant tumors

plt.title('Compare between benign(B) and malignant(M) by radius')
sns.kdeplot(data=df, x='Radius (worst)', hue='Diagnosis', shade=True)
# Out:
# /var/folders/r_/78jds8lj48v17s67b598bgkw0000gn/T/ipykernel_4270/620206258.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df, x='Radius (worst)', hue='Diagnosis', shade=True)
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: title={'center': 'Compare between benign(B) and malignant(M) by radius'}, xlabel='Radius (worst)', ylabel='Density'>
